# %%
# disperse
reload(tx)
from ecc import PrivateKey
from helper import decode_base58, p2pkh_script, SIGHASH_ALL
from script import Script
from tx import TxIn, TxOut, Tx
import requests

target_address = 'muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne'
secret = 61740721216174072121
priv = PrivateKey(secret=secret)
print(priv.point.address(testnet=True))

# initialize inputs
tx_ins = []
target_amount = -0.005  # fee

data = [{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"77c593f0b9c3d7298becdb491d556ec3d4ab7ff7c0115e0b3b5995de76189b9e","vout":8,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.12,"satoshis":12000000,"height":1316501,"confirmations":1},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"3104826ffd9208b560ffc166c30749dc1f2f50f0075ce7b4009291a6b4a205a9","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298058,"confirmations":18444},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"2a3888702a587c57d0be1a793f1b14b7c1085c622ea1ff1a4c1cdf71f19db7e4","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298058,"confirmations":18444},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"4a4cd907f440b42ed8b1763bf282ec81954a27c7341a5e37b81340b3eb8bfbae","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298057,"confirmations":18445},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"8448478ca5fc2afb791c60fc8bec5888448ab5893350276ceafb8a31937b6a07","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298057,"confirmations":18445},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"2e7d840c667aae737059a2cfe68a3d220496ee44ba04e340ffc0842937a56fe9","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298057,"confirmations":18445},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"740175f451d58bfd7608eae07c81d001959f622519bfc1cd48602763a5702fcd","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"8f3d296424e1b38156e56a9c1da89fe6aab836ffcec08beab9e811b64d93fbc0","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"1cf6ede9024a8ca97623e98cbce2d2775149bd43ad27d9bd938035cc574bebd0","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"5d8cd563455689bd0c9bd09a7e2298a90dba400b9be6e05a114fbc0e02a07de6","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"a99f5d7881b5bbc97e81e217963026151db35d73d0f0d919b080a34f4eda8889","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"30540b6cadd35d343547570403c6a0922e11283ab19b849f80572c58875b046d","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"2b35bb9a12b6b4dfec33d28013a982b8a859fa3998a722aa91dd928825eb2558","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"fdb3dd392ff566a8bd939863eea9503e93c1c84a881d2612ccdc9e7c300b7f56","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"4989a7d1d7e8b42154cf21eabd533a6d124483547f424bdf63ee77269abb733e","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"451aa6af9f74f8cdd1ec39c93092d62a0f9155d5073514cd7b225c066b7ffc2f","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"8ca02729b5b3604f0f7fb728ff64dc6fccf863ab9e1e5a86eccdc397e5bc950e","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.02,"satoshis":2000000,"height":1298055,"confirmations":18447},{"address":"muvpVznkBtk8rRSxLRVQRdUhsMjS7aKRne","txid":"502b96195127baf8a3913f0edb6e00cce7ba210ed7cda34221b9e6437edf5ed0","vout":0,"scriptPubKey":"76a9149e153ce5de3689901301309b9e8d804ab4804d4b88ac","amount":0.324,"satoshis":32400000,"height":1298016,"confirmations":18486}]
for item in data:
    prev_tx = bytes.fromhex(item['txid'])
    prev_index = item['vout']
    target_amount += item['amount']
    # create a new tx input
    tx_ins.append(TxIn(
            prev_tx=prev_tx,
            prev_index=prev_index,
            script_sig=b'',
            sequence=0xffffffff,
        ))

# initialize outputs
tx_outs = []
# decode the hash160 from the target address
h160 = decode_base58(target_address)
# convert hash160 to p2pkh script
script_pubkey = p2pkh_script(h160)
# convert target amount to satoshis (multiply by 100 million)
target_satoshis = int(target_amount*100000000)
# create a new tx output for target
tx_outs.append(TxOut(
    amount=target_satoshis,
    script_pubkey=script_pubkey,
))

# create the transaction
tx_obj = Tx(version=1, tx_ins=tx_ins, tx_outs=tx_outs, locktime=0, testnet=True)

# now sign the 0th input with the private key using SIGHASH_ALL using sign_input
for i in range(len(tx_obj.tx_ins)):
    tx_obj.sign_input(i, priv, SIGHASH_ALL)

# SANITY CHECK: change address corresponds to private key
if priv.point.address(testnet=True) != target_address:
    raise RuntimeError('Private Key does not correspond to Change Address, check priv_key and change_address')

# SANITY CHECK: output's script_pubkey is the same one as your address
if tx_ins[0].script_pubkey(testnet=True).elements[2] != decode_base58(target_address):
    raise RuntimeError('Output is not something you can spend with this private key. Check that the prev_tx and prev_index are correct')
    
# SANITY CHECK: fee is reasonable
if tx_obj.fee(testnet=True) > 0.05*100000000 or tx_obj.fee(testnet=True) <= 0:
    raise RuntimeError('Check that the change amount is reasonable. Fee is {}'.format(tx_obj.fee()))

# serialize and hex()
print(tx_obj.serialize().hex())
